// %% [markdown]
// # Stack

// %% [markdown]
// Stack is LIFO. Similar like when you're stacking plates.

// %% [markdown]
// ![stack.png](attachment:62fa557e-3c45-4f73-9ffa-587f29577cf8.png)

// %% [markdown]
// ## Stack Implementation
