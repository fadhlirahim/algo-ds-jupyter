// %% [markdown]
// # Trees
//
// pre-requsite: recursions.
//
// In computer science: many structures and concepts in programming can be thought of or represented as trees.
//
// ## Where are trees?
//
// - File system
// - Dom
// - Trees are important concept in compilers.
//
//
// ## Terminology
//
// root - the most parent node.
//
// height - the longest path from the root to the most childest node. (trees don't have to be balance).
//
// binary tree - a tree with at max 2 children (left/right).
//
// general tree - a tree with 0 or more children.
//
// binary search tree - a tree which has a specific ordering to the nodes and at most 2 children.
//
// leaves - a node without children
//
// balanced - a tree is perfectly balanced when any node's left and right children have the same height.
//
// branching factor - the amount of children a tree has.
//
// ## Traversals
//
// ### Depth First Search
//
// A traversal is an attempt to visit every single node.
// - pre order
// - in order
// - post order
//
//
//
// ![Screenshot 2024-01-04 at 7.19.35 PM.png](attachment:cc57d3e2-45a6-4b68-a738-2a199122a8e4.png)
//
// A Depth First Search basically operates like a stack
//
// See
//
// ```
// src/BTInorder.ts
// src/BTIPreOrder.ts
// src/BTIPostOrder.ts
// ```
//
// ### Breadth-First Search
//
// ![Screenshot 2024-01-05 at 4.46.03 PM.png](attachment:4c691fcb-a7f8-4935-82df-36b9745b6f4c.png)
