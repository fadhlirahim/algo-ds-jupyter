// %% [markdown]
// # Linear Search
//
// ## Assumptions
//
// - We only have access to .length property of an array

// %% [markdown]
//  ![search.png](attachment:search.png)

// %% [markdown]
// Big-O: O(N)

// %%
export default function linear_search(haystack: number[], needle: number): boolean {
    
    for(let i = 0; i < haystack.length; ++i){
        if(haystack[i] === needle){
            return true;
        }
    }
    return false;
}
linear_search([1,2], 1)
// Out:
// true

// %%
linear_search([1,2], 3)
// Out:
// false
